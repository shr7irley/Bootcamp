# %% [markdown]
# # El desafío
#
# 4. Crear una instancia de EC2 de Amazon Linux para ejecutar una aplicación web. Los pasos generales son los siguientes:
#
# Utilice la Consola de administración de AWS para lanzar la instancia.
#
# Utilice una Imagen de máquina de Amazon (AMI) de Amazon Linux y un tipo de instancia T3 de tamaño inferior al mediano.
#
# Lance la instancia en una nueva nube virtual privada (VPC) y una nueva subred, y asigne automáticamente la dirección IPv4 pública de la instancia.
#
# Mientras se crea la instancia, en los datos de usuario, instale y comience el servicio httpd como su servidor web. Otorgue permiso de escritura a los usuarios en el directorio raíz de documentos del servidor web (/var/www/html).
#
# Utilice un tipo de volumen SSD de uso general (gp2) para el volumen raíz.
#
# Configure la instancia y cree los recursos necesarios para poder conectarse a ella mediante Secure Shell (SSH).
#
# Tome una captura de pantalla del registro del sistema de la instancia de EC2 que muestra que el servicio httpd se instaló correctamente.
#
# 5. Para probar su servidor web, implemente la página web de los siguientes pasos en su servidor web.
#
# Utilice EC2 Instance Connect para conectarse a su instancia de EC2.
#
# Copie el siguiente código HTML y péguelo en un editor de texto:

# %%
<!DOCTYPE html>
<html>
<body>
<h1>YOUR-NAME's re/Start Project Work</h1>
<p>EC2 Instance Challenge Lab</p>
</body>
</html>

# %% [markdown]
# Reemplace YOUR-NAME por su nombre y guarde el archivo como projects.html.
#
# Coloque este archivo en el directorio /var/www/html de su instancia de EC2.
#
# Abra un navegador web y diríjase hasta esta página web de ejemplo. Tome una captura de pantalla que muestre que la página se devolvió y se visualizó correctamente.
#
# Envíe las capturas de pantalla que tomó a su instructor.
#
# ## Sugerencias
#
# Deberá crear una puerta de enlace de internet y configurar correctamente la tabla de enrutamiento de la subred en su VPC antes de lanzar su instancia.
#
# Deberá usar EC2 Instance Connect para conectarse a través de SSH a su instancia de EC2 mediante un navegador web.
#
# Asegúrese de que dispone de la configuración del grupo de seguridad adecuada. En particular, debe permitir el tráfico SSH y HTTP.
#
# Utilice la dirección IPv4 pública de la instancia para acceder a su página web.
#
# Deberá aumentar los privilegios con el comando sudo para copiar el archivo en el directorio /var/www/html/.
#
# Consulte los siguientes laboratorios para obtener orientación adicional:
#
# Creación de instancias de Amazon EC2
#
# # Laboratorio completado
#  ¡Felicitaciones! Ha completado este laboratorio de desafío.
