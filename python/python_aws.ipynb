# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
print(3+5)
# Out:
# 8

# %%
pelicula=("Tog Gun")
Year=2020
buena_peli=False
print("La pelicula", pelicula, "Salio en el", Year, "fue genial?", buena_peli)
# Out:
# La pelicula Tog Gun Salio en el 2020 fue genial? False
