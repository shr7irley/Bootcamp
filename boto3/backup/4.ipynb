# %%
# !aws cloudformation describe-stacks --stack-name mi-stack-web
# Out:
# aws: [ERROR]: An error occurred (ValidationError) when calling the DescribeStacks operation: Stack with id mi-stack-web does not exist
#
# Additional error details:
# Type: Sender
